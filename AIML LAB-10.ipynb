# %% [markdown]
# <a href="https://colab.research.google.com/github/DEEPAK-RAMGIRI/AIML-LAB/blob/main/LAB_010.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # IMPLEMENT K-MEANS CLUSTERING USING SYNTHETIC DATA

# %%
import matplotlib.pyplot as mt
import numpy as np
import pandas as pd
import seaborn as sns
sns.set() # plot stylings

# %%
from sklearn.datasets import make_blobs
X,y_true = make_blobs(n_samples = 300,centers=4,cluster_std=0.60,random_state=0)
mt.scatter(X[:,0],X[:,1],s=50,color='blue')
