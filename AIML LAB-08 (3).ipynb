# %% [markdown]
# <a href="https://colab.research.google.com/github/DEEPAK-RAMGIRI/AIML-LAB/blob/main/LAB_008.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as mt
import numpy as np
import pandas as pd
import seaborn as sns
# %matplotlib inline

# %%
from sklearn.datasets import fetch_openml
car_data=fetch_openml(name='car',version=2,parser='auto')

# %%
car_data.details
# Out:
# {'id': '991',
#  'name': 'car',
#  'version': '2',
#  'description_version': '1',
#  'format': 'ARFF',
#  'upload_date': '2014-10-04T22:44:31',
#  'licence': 'Public',
#  'url': 'https://api.openml.org/data/v1/download/53525/car.arff',
#  'parquet_url': 'https://openml1.win.tue.nl/datasets/0000/0991/dataset_991.pq',
#  'file_id': '53525',
#  'default_target_attribute': 'binaryClass',
#  'tag': ['Chemistry',
#   'derived',
#   'Life Science',
#   'mythbusting_1',
#   'study_1',
#   'study_15',
#   'study_20',
#   'study_41',
#   'study_7'],
#  'visibility': 'public',
#  'minio_url': 'https://openml1.win.tue.nl/datasets/0000/0991/dataset_991.pq',
#  'status': 'active',
#  'processing_date': '2020-11-20 20:17:54',
#  'md5_checksum': '49c57b793eef1b8e55f297e5e019fdbf'}

# %%
car_data.details['version']
# Out:
# '2'

# %%
#GETTING WHOLE CAR DATA FRAMES
car_data=car_data.frame
car_data.head()
# Out:
#   buying  maint doors persons lug_boot safety binaryClass
# 0  vhigh  vhigh     2       2    small    low           P
# 1  vhigh  vhigh     2       2    small    med           P
# 2  vhigh  vhigh     2       2    small   high           P
# 3  vhigh  vhigh     2       2      med    low           P
# 4  vhigh  vhigh     2       2      med    med           P

# %%
type(car_data)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# #Splitting data into training and test sets

# %% [markdown]
# * Training and testing data

# %%
from sklearn.model_selection import train_test_split
train_data,test_data=train_test_split(car_data,test_size=0.3,random_state=20)
print("The size of training data is:{} \n the size of testing data is:{}".format(len(train_data),len(test_data)))
# train and test retio is 70 and 30 percents
# Out:
# The size of training data is:1209
#  the size of testing data is:519

# %% [markdown]
# * checking for summary statistics

# %%
#checking summary statistics
train_data.describe()
# Out:
#        buying maint  doors persons lug_boot safety binaryClass
# count    1209  1209   1209    1209     1209   1209        1209
# unique      4     4      4       3        3      3           2
# top       med  high  5more    more      big    med           P
# freq      327   311    319     418      411    406         849

# %% [markdown]
# * Checking for the missing values

# %%
train_data.isnull().sum()
#Here if we get "1" value, then there is a missing a value.
# Out:
# buying         0
# maint          0
# doors          0
# persons        0
# lug_boot       0
# safety         0
# binaryClass    0
# dtype: int64

# %% [markdown]
# * checking for categorical features

# %%
train_data['buying'].value_counts()
# Out:
# med      327
# high     307
# vhigh    291
# low      284
# Name: buying, dtype: int64

# %%
mt.figure(figsize=(15,20))
sns.countplot(data=train_data,x='buying')
# Out:
# <Axes: xlabel='buying', ylabel='count'>

# %%
mt.figure(figsize=(15,10))
sns.countplot(data=train_data,x='buying',hue="binaryClass")
#According to graph we can decide to buy the car
# Out:
# <Axes: xlabel='buying', ylabel='count'>

# %%
train_data['maint'].value_counts()
# Out:
# high     311
# med      311
# vhigh    294
# low      293
# Name: maint, dtype: int64

# %%
mt.figure(figsize=(15,20))
sns.countplot(data=train_data,x='maint')
# Out:
# <Axes: xlabel='maint', ylabel='count'>

# %%
mt.figure(figsize=(15,10))
sns.countplot(data=train_data,x='maint',hue="binaryClass")
# Out:
# <Axes: xlabel='maint', ylabel='count'>

# %%
train_data['doors'].value_counts()
# Out:
# 5more    319
# 2        312
# 4        296
# 3        282
# Name: doors, dtype: int64

# %%
mt.figure(figsize=(15,20))
sns.countplot(data=train_data,x='doors')
# Out:
# <Axes: xlabel='doors', ylabel='count'>

# %%
mt.figure(figsize=(15,10))
sns.countplot(data=train_data,x='doors',hue="binaryClass")
# Out:
# <Axes: xlabel='doors', ylabel='count'>

# %%
train_data['persons'].value_counts()
# Out:
# more    418
# 2       407
# 4       384
# Name: persons, dtype: int64

# %%
mt.figure(figsize=(15,20))
sns.countplot(data=train_data,x='persons')
# Out:
# <Axes: xlabel='persons', ylabel='count'>

# %%
mt.figure(figsize=(15,10))
sns.countplot(data=train_data,x='persons',hue="binaryClass")
# Out:
# <Axes: xlabel='persons', ylabel='count'>

# %%
train_data['lug_boot'].value_counts()
# Out:
# big      411
# med      405
# small    393
# Name: lug_boot, dtype: int64

# %%
mt.figure(figsize=(15,20))
sns.countplot(data=train_data,x='lug_boot')
# Out:
# <Axes: xlabel='lug_boot', ylabel='count'>

# %%
mt.figure(figsize=(15,10))
sns.countplot(data=train_data,x='lug_boot',hue="binaryClass")
# Out:
# <Axes: xlabel='lug_boot', ylabel='count'>

# %%
train_data['safety'].value_counts()
# Out:
# med     406
# low     402
# high    401
# Name: safety, dtype: int64

# %%
mt.figure(figsize=(15,20))
sns.countplot(data=train_data,x='safety')
# Out:
# <Axes: xlabel='safety', ylabel='count'>

# %%
mt.figure(figsize=(15,10))
sns.countplot(data=train_data,x='maint',hue="safety")
# Out:
# <Axes: xlabel='maint', ylabel='count'>

# %%
train_data['binaryClass'].value_counts()
# Out:
# P    849
# N    360
# Name: binaryClass, dtype: int64

# %%
mt.figure(figsize=(15,20))
sns.countplot(data=train_data,x='binaryClass')
# Out:
# <Axes: xlabel='binaryClass', ylabel='count'>

# %%
mt.figure(figsize=(15,10))
sns.countplot(data=train_data,x='binaryClass',hue="binaryClass")
# Out:
# <Axes: xlabel='binaryClass', ylabel='count'>

# %%
car_train=train_data.drop('binaryClass',axis=1)
car_labels=train_data[['binaryClass']]

# %%
from sklearn.preprocessing import OrdinalEncoder
from sklearn.pipeline import Pipeline
pipe =Pipeline([('ord_enc',OrdinalEncoder())])
car_train_prepared=pipe.fit_transform(car_train)

# %%
from sklearn.preprocessing import LabelEncoder
label_enc=LabelEncoder()
car_label_prepared=label_enc.fit_transform(car_labels)

# %%
from sklearn.tree import DecisionTreeClassifier
tree_clf =DecisionTreeClassifier()
tree_clf.fit(car_train_prepared,car_label_prepared)
# Out:
# DecisionTreeClassifier()

# %%
from sklearn.metrics import accuracy_score
def accuracy(input_data,model,labels):
  """
  Take the imput data,model and labels and return accuracy
  """
  preds=model.predict(input_data)
  acc=accuracy_score(labels,preds)
  return acc

# %%
from sklearn.metrics import confusion_matrix
def conf_matrix(input_data,model,labels):
  """
  Take the imput data,model and labels and return confusion matrix
  """
  preds=model.predict(input_data)
  cm=confusion_matrix(labels,preds)
  return cm

# %%
from sklearn.metrics import classification_report
def class_report(input_data,model,labels):
  preds=model.predict(input_data)
  report=classification_report(labels,preds)
  report=print(report)
  return report

# %%
accuracy(car_train_prepared,tree_clf,car_label_prepared)
# Out:
# 1.0

# %%
conf_matrix(car_train_prepared,tree_clf,car_label_prepared)
# Out:
# array([[360,   0],
#        [  0, 849]])

# %%
class_report(car_train_prepared,tree_clf,car_label_prepared)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       360
#            1       1.00      1.00      1.00       849
#
#     accuracy                           1.00      1209
#    macro avg       1.00      1.00      1.00      1209
# weighted avg       1.00      1.00      1.00      1209
